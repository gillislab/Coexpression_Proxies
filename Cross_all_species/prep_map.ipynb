# %%
import pandas as pd
import numpy as np

# %%
pandas_map = pd.read_csv('/data/passala/git/Coexpressalog_Method_Development/Cross_all_species/map_of_ortholog_map_locations.csv', index_col= 0)
numpy_map = np.asarray(pandas_map)

# %%
i_lower = np.tril_indices(13, -1)
numpy_map[i_lower] = numpy_map.T[i_lower]

# %%
pandas_map[:] = numpy_map
pandas_map
# Out:
#                                                          apple  \
# apple                                                      NaN
# rice         /data/CoCoCoNet/orthologMaps/apple_rice_orthoN...
# sorghum      /data/CoCoCoNet/orthologMaps/apple_sorghum_ort...
# maize        /data/CoCoCoNet/orthologMaps/apple_maize_ortho...
# grape        /data/CoCoCoNet/orthologMaps/apple_grape_ortho...
# mustard      /data/CoCoCoNet/orthologMaps/mustard_apple_ort...
# soybean      /data/CoCoCoNet/orthologMaps/apple_soybean_ort...
# medicago     /data/CoCoCoNet/orthologMaps/apple_medicago_or...
# tobacco      /data/CoCoCoNet/orthologMaps/apple_tobacco_ort...
# potato       /data/CoCoCoNet/orthologMaps/apple_potato_orth...
# arabidopsis  /data/CoCoCoNet/orthologMaps/arabidopsis_apple...
# brome        /data/CoCoCoNet/orthologMaps/apple_brome_ortho...
# tomato       /data/CoCoCoNet/orthologMaps/apple_tomato_orth...
#
#                                                           rice  \
# ...

# %%
pandas_map.to_csv('/data/passala/git/Coexpressalog_Method_Development/Cross_all_species/map_of_ortholog_map_locations.csv')
