# %%
import pandas as pd
import CococoNet_reader 
import itertools
import numpy as np

# %%
maize_rice_map = pd.read_csv('/data/CoCoCoNet/orthologMaps/maize_rice_orthoNM.csv')

# %%
maize_rice_map
# Out:
#                 maize          rice  maize_OrthoID    rice_OrthoID
# 0      Zm00001d037751  Os01g0195400  4577_0:005cb7  39947_0:000000
# 1      Zm00001d008850  Os01g0195400  4577_0:007339  39947_0:000000
# 2      Zm00001d009823  Os01g0825000  4577_0:00713c  39947_0:000001
# 3      Zm00001d043036  Os01g0825000  4577_0:00298e  39947_0:000001
# 4      Zm00001d040218  Os01g0101600  4577_0:0033c6  39947_0:000002
# ...               ...           ...            ...             ...
# 24341  Zm00001d040880      BAC19899  4577_0:002c65  39947_0:006d33
# 24342   GRMZM5G890451      BAC19857  4577_0:00916d  39947_0:006d34
# 24343  Zm00001d013779      BAC19887  4577_0:004fad  39947_0:006d36
# 24344  Zm00001d033105      BAC19887  4577_0:000cc9  39947_0:006d36
# 24345   GRMZM5G851130      BAC19874  4577_0:009170  39947_0:006d3a
#
# [24346 rows x 4 columns]

# %%
maize_rice_map_one_to_one = maize_rice_map.drop_duplicates(subset='rice', keep= False,)
maize_rice_map_one_to_one = maize_rice_map_one_to_one.drop_duplicates(subset= 'maize', keep= False)
maize_rice_map_one_to_one
# Out:
#                 maize          rice  maize_OrthoID    rice_OrthoID
# 7      Zm00001d008326  Os01g0256800  4577_0:0073fc  39947_0:000006
# 8      Zm00001d042875  Os01g0847100  4577_0:002d68  39947_0:000007
# 13     Zm00001d039878  Os01g0144300  4577_0:002e3e  39947_0:00000b
# 14     Zm00001d012590  Os01g0796400  4577_0:007800  39947_0:00000d
# 15     Zm00001d042520  Os01g0897100  4577_0:002744  39947_0:00000e
# ...               ...           ...            ...             ...
# 24339   GRMZM5G839924      BAC19900  4577_0:009114  39947_0:006d26
# 24340   GRMZM5G889905      BAC19903  4577_0:00912e  39947_0:006d32
# 24341  Zm00001d040880      BAC19899  4577_0:002c65  39947_0:006d33
# 24342   GRMZM5G890451      BAC19857  4577_0:00916d  39947_0:006d34
# 24345   GRMZM5G851130      BAC19874  4577_0:009170  39947_0:006d3a
#
# [5471 rows x 4 columns]

# %%
#maize_rice_map_one_to_one.to_csv('/data/passala/Generated_Tables/Maize_Rice_integration/maize_rice_one_to_one.csv', index = False)

# %%
dictionary_mapper_rice_to_maize = maize_rice_map_one_to_one.set_index("rice").to_dict()['maize']
dictionary_mapper_maize_to_rice = maize_rice_map_one_to_one.set_index('maize').to_dict()['rice']

# %%
rice_cococonet = CococoNet_reader.read_cococonet('rice')
maize_cococonet = CococoNet_reader.read_cococonet('maize')

# %%
rice_cococonet
# Out:
#                     Os01g0100100  Os01g0100200  Os01g0100300  Os01g0100400  \
# Os01g0100100            1.000000      0.415044      0.480129      0.954701
# Os01g0100200            0.415044      1.000000      0.475633      0.752125
# Os01g0100300            0.480129      0.475633      1.000000      0.472164
# Os01g0100400            0.954701      0.752125      0.472164      1.000000
# Os01g0100466            0.448483      0.390407      0.491006      0.467006
# ...                          ...           ...           ...           ...
# CAA33925                0.454757      0.381620      0.494493      0.453827
# ENSRNA050013646         0.614028      0.614028      0.614028      0.614028
# CAA33926                0.421163      0.346238      0.483356      0.567841
# EPlORYSAT000373848      0.614028      0.614028      0.614028      0.614028
# CAA33927                0.437491      0.476471      0.473212      0.303638
#
# ...

# %%
maize_rice_map['Group ID'] = 'Unassigned'

# %%
id_indexer = 0
for gene_pair in maize_rice_map.iterrows():
    
    if gene_pair[1]['Group ID'] == 'Unassigned':
        current_rice_gene = gene_pair[1]['rice']
        current_maize_gene = gene_pair[1]['maize']
        maize_rice_map['Group ID'].loc[(maize_rice_map['rice'] == current_rice_gene) & (maize_rice_map['Group ID'] == 'Unassigned')] = id_indexer
        maize_rice_map['Group ID'].loc[(maize_rice_map['maize'] == current_maize_gene) & (maize_rice_map['Group ID'] == 'Unassigned')] = id_indexer

        all_labeled_groups = maize_rice_map.loc[maize_rice_map['Group ID'] == id_indexer]

        all_labeled_groups_rice_genes = all_labeled_groups['rice'].to_list()
        all_labeled_groups_maize_genes = all_labeled_groups['maize'].to_list()

        maize_rice_map['Group ID'].loc[maize_rice_map['rice'].isin(all_labeled_groups_rice_genes)] = id_indexer
        maize_rice_map['Group ID'].loc[maize_rice_map['maize'].isin(all_labeled_groups_maize_genes)] = id_indexer

        id_indexer += 1

# %%
maize_rice_map
# Out:
#                 maize          rice  maize_OrthoID    rice_OrthoID Group ID
# 0      Zm00001d037751  Os01g0195400  4577_0:005cb7  39947_0:000000        0
# 1      Zm00001d008850  Os01g0195400  4577_0:007339  39947_0:000000        0
# 2      Zm00001d009823  Os01g0825000  4577_0:00713c  39947_0:000001        1
# 3      Zm00001d043036  Os01g0825000  4577_0:00298e  39947_0:000001        1
# 4      Zm00001d040218  Os01g0101600  4577_0:0033c6  39947_0:000002        2
# ...               ...           ...            ...             ...      ...
# 24341  Zm00001d040880      BAC19899  4577_0:002c65  39947_0:006d33     9427
# 24342   GRMZM5G890451      BAC19857  4577_0:00916d  39947_0:006d34     9428
# 24343  Zm00001d013779      BAC19887  4577_0:004fad  39947_0:006d36     9429
# 24344  Zm00001d033105      BAC19887  4577_0:000cc9  39947_0:006d36     9429
# 24345   GRMZM5G851130      BAC19874  4577_0:009170  39947_0:006d3a     9430
#
# [24346 rows x 5 columns]

# %%
#maize_rice_map.to_csv('/data/passala/Generated_Tables/Temp_junk/maize_rice_map_with_group_id.csv',index= False)

# %%
all_pairs_to_evaluate_for_functional_conservation = pd.DataFrame(columns = ['Rice','Maize','Group Number'])
for group_number in list(set(maize_rice_map['Group ID'].to_list())):
    current_gene_map = maize_rice_map.loc[maize_rice_map['Group ID'] == group_number]
    list_of_rice_genes_in_group = list(set(current_gene_map['rice'].to_list()))
    list_of_maize_genes_in_group = list(set(current_gene_map['maize'].to_list()))
    all_combo_list_current_genes = itertools.product(list_of_rice_genes_in_group,list_of_maize_genes_in_group)
    all_combo_list_current_genes = list(map(list,all_combo_list_current_genes))
    current_list_of_pairs = pd.DataFrame(all_combo_list_current_genes,columns = ['Rice','Maize'])
    current_list_of_pairs['Group Number'] = group_number
    all_pairs_to_evaluate_for_functional_conservation = all_pairs_to_evaluate_for_functional_conservation.append(current_list_of_pairs)
# Out:
# /tmp/ipykernel_2027065/844368316.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_pairs_to_evaluate_for_functional_conservation = all_pairs_to_evaluate_for_functional_conservation.append(current_list_of_pairs)
# /tmp/ipykernel_2027065/844368316.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_pairs_to_evaluate_for_functional_conservation = all_pairs_to_evaluate_for_functional_conservation.append(current_list_of_pairs)
# /tmp/ipykernel_2027065/844368316.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_pairs_to_evaluate_for_functional_conservation = all_pairs_to_evaluate_for_functional_conservation.append(current_list_of_pairs)
# ...

# %%
all_pairs_to_evaluate_for_functional_conservation['Rice Score'] = np.nan
all_pairs_to_evaluate_for_functional_conservation['Maize Score'] = np.nan
#all_pairs_to_evaluate_for_functional_conservation.to_csv('/home/passala/git/Coexpressalog_Method_Development/all_pairs_From_maize.csv',index = False)

# %%
trimmed_rice_cococonet = rice_cococonet[rice_cococonet.columns.intersection(maize_rice_map['rice'].to_list())]
trimmed_rice_cococonet = trimmed_rice_cococonet[trimmed_rice_cococonet.index.isin(maize_rice_map['rice'].to_list())]
double_rice_trimmed_cococonet = trimmed_rice_cococonet[trimmed_rice_cococonet.columns.intersection(maize_rice_map_one_to_one['rice'].to_list())]
double_rice_trimmed_cococonet = double_rice_trimmed_cococonet.replace(1,0)

trimmed_maize_cococonet = maize_cococonet[maize_cococonet.columns.intersection(maize_rice_map['maize'].to_list())]
trimmed_maize_cococonet = trimmed_maize_cococonet[trimmed_maize_cococonet.index.isin(maize_rice_map['maize'].to_list())]
double_maize_trimmed_cococonet = trimmed_maize_cococonet[trimmed_maize_cococonet.columns.intersection(maize_rice_map_one_to_one['maize'].to_list())]
double_maize_trimmed_cococonet = double_maize_trimmed_cococonet.replace(1,0)

# %%
double_maize_trimmed_cococonet
# Out:
#                 Zm00001d027267  Zm00001d027276  Zm00001d027283  \
# Zm00001d027267        0.000000        0.974850        0.611214
# Zm00001d027268        0.609728        0.323943        0.306585
# Zm00001d027276        0.974850        0.000000        0.641635
# Zm00001d027283        0.611214        0.641635        0.000000
# Zm00001d027292        0.511637        0.337024        0.455827
# ...                        ...             ...             ...
# Zm00001d000434        0.598269        0.567444        0.124157
# Zm00001d000435        0.759677        0.858523        0.503390
# Zm00001d000439        0.855829        0.830214        0.603840
# Zm00001d000443        0.772530        0.712977        0.755203
# Zm00001d000447        0.250021        0.428373        0.158172
#
#                 Zm00001d027292  Zm00001d027304  Zm00001d027309  \
# Zm00001d027267        0.511637        0.625680        0.895038
# Zm00001d027268        0.748024        0.390650        0.654704
# ...

# %%
double_rice_trimmed_cococonet
# Out:
#               Os01g0102500  Os01g0102600  Os01g0102800  Os01g0102900  \
# Os01g0100100      0.790527      0.943200      0.950192      0.933527
# Os01g0100600      0.800079      0.907646      0.985734      0.974686
# Os01g0100700      0.749391      0.816232      0.881454      0.843489
# Os01g0100800      0.841500      0.904354      0.991614      0.896266
# Os01g0101600      0.906027      0.953427      0.977614      0.849930
# ...                    ...           ...           ...           ...
# CAA33908          0.545683      0.706010      0.698777      0.422955
# CAA33912          0.186968      0.574059      0.316578      0.761953
# CAA33919          0.496275      0.675196      0.495098      0.570852
# CAA33920          0.269292      0.721823      0.103887      0.413379
# CAA33925          0.460946      0.524589      0.448958      0.413556
#
#               Os01g0103100  Os01g0104000  Os01g0104400  Os01g0104500  \
# ...

# %%
maize_cococonet_ranked = trimmed_maize_cococonet.rank()
rice_cococonet_ranked = trimmed_rice_cococonet.rank()

# %%
top_10_rice_genes = np.array(
    [double_rice_trimmed_cococonet.T[c].nlargest(10).index.values for c in double_rice_trimmed_cococonet.T]
)  # using pair list above, cut down top 10 list to relevant genes, probably by adding list as a column in panda and then filtering panda to index of pair list
top_10_rice_genes_dataframe = pd.DataFrame(
    data=top_10_rice_genes,
    index=double_rice_trimmed_cococonet.index,
    columns=[
        "One",
        "Two",
        "Three",
        "Four",
        "Five",
        "Six",
        "Seven",
        "Eight",
        "Nine",
        "Ten",
    ],
)
top_10_rice_genes_dataframe
# Out:
#                        One           Two         Three          Four  \
# Os01g0100100  Os03g0163300  Os07g0477500  Os02g0280400  Os11g0572100
# Os01g0100600  Os03g0862100  Os03g0597200  Os02g0608100  Os11g0265400
# Os01g0100700  Os07g0180900  Os07g0616600  Os02g0591700  Os03g0577000
# Os01g0100800  Os07g0138100  Os05g0150600  Os02g0105000  Os05g0452600
# Os01g0101600  Os09g0560900  Os11g0661000  Os12g0620000  Os03g0270200
# ...                    ...           ...           ...           ...
# CAA33908          CAA33955      CAA33979      CAA33954      CAA34009
# CAA33912      Os03g0414400  Os02g0596000  Os03g0856500  Os01g0966200
# CAA33919      Os08g0458600  Os01g0805000  Os03g0284400  Os03g0843400
# CAA33920          CAA34007  Os07g0414000  Os11g0267000  Os07g0544800
# CAA33925      Os01g0765600  Os01g0193500  Os01g0338100  Os01g0691300
#
#                       Five           Six         Seven         Eight  \
# ...

# %%
top_10_rice_genes_as_maize = top_10_rice_genes_dataframe.replace(to_replace=dictionary_mapper_rice_to_maize)
top_10_rice_genes_as_maize
# Out:
#                          One             Two           Three            Four  \
# Os01g0100100  Zm00001d027769  Zm00001d050244  Zm00001d053316  Zm00001d007500
# Os01g0100600  Zm00001d034935  Zm00001d032399  Zm00001d017164  Zm00001d004616
# Os01g0100700  Zm00001d018957  Zm00001d006871  Zm00001d017047  Zm00001d024511
# Os01g0100800  Zm00001d007849  Zm00001d010866  Zm00001d054077  Zm00001d038686
# Os01g0101600  Zm00001d006344  Zm00001d038206  Zm00001d041298  Zm00001d028579
# ...                      ...             ...             ...             ...
# CAA33908       GRMZM5G835775   GRMZM5G879235   GRMZM5G815553   GRMZM5G811749
# CAA33912      Zm00001d039070  Zm00001d013997  Zm00001d034897  Zm00001d011797
# CAA33919      Zm00001d032057  Zm00001d043170  Zm00001d028702  Zm00001d034808
# CAA33920      Zm00001d000417  Zm00001d052042  Zm00001d023427  Zm00001d021703
# CAA33925      Zm00001d043346  Zm00001d039481  Zm00001d040757  Zm00001d011630
#
# ...

# %%
have_rice_pairs = all_pairs_to_evaluate_for_functional_conservation.loc[all_pairs_to_evaluate_for_functional_conservation['Rice'].isin(top_10_rice_genes_as_maize.index)]
trimmed_all_gene_pairs_for_fc = have_rice_pairs.loc[have_rice_pairs['Maize'].isin(trimmed_maize_cococonet.index)]
trimmed_all_gene_pairs_for_fc = trimmed_all_gene_pairs_for_fc.reset_index(drop = True)
trimmed_all_gene_pairs_for_fc
# Out:
#                Rice           Maize Group Number  Rice Score  Maize Score
# 0      Os05g0199100  Zm00001d037751            0         NaN          NaN
# 1      Os05g0199100  Zm00001d008850            0         NaN          NaN
# 2      Os01g0195400  Zm00001d037751            0         NaN          NaN
# 3      Os01g0195400  Zm00001d008850            0         NaN          NaN
# 4      Os01g0825000  Zm00001d043036            1         NaN          NaN
# ...             ...             ...          ...         ...          ...
# 21920      BAC19875   GRMZM5G804358         9421         NaN          NaN
# 21921      BAC19898  Zm00001d018755         9423         NaN          NaN
# 21922      BAC19857   GRMZM5G890451         9428         NaN          NaN
# 21923      BAC19887  Zm00001d013779         9429         NaN          NaN
# 21924      BAC19887  Zm00001d033105         9429         NaN          NaN
#
# [21925 rows x 5 columns]

# %%
for two_genes in trimmed_all_gene_pairs_for_fc.iterrows():
    current_rice_gene = two_genes[1]['Rice']
    current_maize_gene = two_genes[1]['Maize']
    finger_print_genes = top_10_rice_genes_as_maize.loc[current_rice_gene].to_list()
    gene_ranks_in_maize = maize_cococonet_ranked.loc[maize_cococonet_ranked.index.isin(finger_print_genes), current_maize_gene]
    avg_rank_in_maize = gene_ranks_in_maize.mean()
    index_from_pairs = two_genes[0]
    trimmed_all_gene_pairs_for_fc.at[index_from_pairs, 'Rice Score'] = avg_rank_in_maize

# %%
trimmed_all_gene_pairs_for_fc
# Out:
#                Rice           Maize Group Number    Rice Score  Maize Score
# 0      Os05g0199100  Zm00001d037751            0  10813.900000          NaN
# 1      Os05g0199100  Zm00001d008850            0   9938.500000          NaN
# 2      Os01g0195400  Zm00001d037751            0  11389.200000          NaN
# 3      Os01g0195400  Zm00001d008850            0  12544.700000          NaN
# 4      Os01g0825000  Zm00001d043036            1   8325.500000          NaN
# ...             ...             ...          ...           ...          ...
# 21920      BAC19875   GRMZM5G804358         9421  12669.428571          NaN
# 21921      BAC19898  Zm00001d018755         9423   6234.750000          NaN
# 21922      BAC19857   GRMZM5G890451         9428  11712.142857          NaN
# 21923      BAC19887  Zm00001d013779         9429   3136.500000          NaN
# 21924      BAC19887  Zm00001d033105         9429   3335.000000          NaN
#
# [21925 rows x 5 columns]

# %%
top_10_maize_genes = np.array(
    [double_maize_trimmed_cococonet.T[c].nlargest(10).index.values for c in double_maize_trimmed_cococonet.T]
)  # using pair list above, cut down top 10 list to relevant genes, probably by adding list as a column in panda and then filtering panda to index of pair list
top_10_maize_genes_dataframe = pd.DataFrame(
    data=top_10_maize_genes,
    index=double_maize_trimmed_cococonet.index,
    columns=[
        "One",
        "Two",
        "Three",
        "Four",
        "Five",
        "Six",
        "Seven",
        "Eight",
        "Nine",
        "Ten",
    ],
)
top_10_maize_genes_dataframe
# Out:
#                            One             Two           Three  \
# Zm00001d027267  Zm00001d029036  Zm00001d016248  Zm00001d037900
# Zm00001d027268  Zm00001d022588  Zm00001d018530  Zm00001d021195
# Zm00001d027276  Zm00001d051869  Zm00001d049083  Zm00001d020486
# Zm00001d027283  Zm00001d027965  Zm00001d002026  Zm00001d044677
# Zm00001d027292  Zm00001d051611  Zm00001d014793  Zm00001d011239
# ...                        ...             ...             ...
# Zm00001d000434  Zm00001d020636  Zm00001d029597  Zm00001d026490
# Zm00001d000435  Zm00001d032567  Zm00001d014343  Zm00001d025739
# Zm00001d000439  Zm00001d002433  Zm00001d052007  Zm00001d044367
# Zm00001d000443  Zm00001d014967  Zm00001d006640  Zm00001d049817
# Zm00001d000447  Zm00001d009700  Zm00001d019358  Zm00001d021668
#
#                           Four            Five             Six  \
# Zm00001d027267  Zm00001d031259  Zm00001d048824  Zm00001d046456
# Zm00001d027268  Zm00001d007092  Zm00001d021620  Zm00001d023536
# ...

# %%
top_10_maize_genes_as_rice = top_10_maize_genes_dataframe.replace(to_replace=dictionary_mapper_maize_to_rice)
top_10_maize_genes_as_rice
# Out:
#                          One           Two         Three          Four  \
# Zm00001d027267  Os03g0332400  Os02g0232400  Os05g0372400  Os08g0483600
# Zm00001d027268  Os07g0694800  Os02g0828566  Os09g0520600  Os12g0541500
# Zm00001d027276  Os02g0823600  Os11g0265200  Os09g0416800  Os07g0295200
# Zm00001d027283  Os03g0186900  Os04g0654600  Os11g0448700  Os07g0475400
# Zm00001d027292  Os02g0711900  Os06g0717200  Os01g0587300  Os06g0691600
# ...                      ...           ...           ...           ...
# Zm00001d000434  Os09g0442300  Os03g0440900  Os04g0656100  Os08g0107100
# Zm00001d000435  Os10g0498700  Os10g0115600  Os04g0488000  Os05g0510300
# Zm00001d000439  Os04g0600400  Os02g0803400  Os01g0593600  Os05g0402300
# Zm00001d000443  Os02g0110600  Os07g0572600  Os08g0531200  Os07g0620300
# Zm00001d000447  Os05g0584200  Os07g0274700  Os07g0529800  Os01g0185300
#
#                         Five           Six         Seven         Eight  \
# ...

# %%
for two_genes in trimmed_all_gene_pairs_for_fc.iterrows():
    current_rice_gene = two_genes[1]['Rice']
    current_maize_gene = two_genes[1]['Maize']
    finger_print_genes = top_10_maize_genes_as_rice.loc[current_maize_gene].to_list()
    gene_ranks_in_rice = rice_cococonet_ranked.loc[rice_cococonet_ranked.index.isin(finger_print_genes), current_rice_gene]
    avg_rank_in_rice = gene_ranks_in_rice.mean()
    index_from_pairs = two_genes[0]
    trimmed_all_gene_pairs_for_fc.loc[index_from_pairs, 'Maize Score'] = avg_rank_in_rice

# %%
trimmed_all_gene_pairs_for_fc
# Out:
#                Rice           Maize Group Number    Rice Score  Maize Score
# 0      Os05g0199100  Zm00001d037751            0  10813.900000      11708.7
# 1      Os05g0199100  Zm00001d008850            0   9938.500000      11908.6
# 2      Os01g0195400  Zm00001d037751            0  11389.200000      11132.4
# 3      Os01g0195400  Zm00001d008850            0  12544.700000      12129.9
# 4      Os01g0825000  Zm00001d043036            1   8325.500000       8959.2
# ...             ...             ...          ...           ...          ...
# 21920      BAC19875   GRMZM5G804358         9421  12669.428571      11419.8
# 21921      BAC19898  Zm00001d018755         9423   6234.750000       7752.6
# 21922      BAC19857   GRMZM5G890451         9428  11712.142857      11082.0
# 21923      BAC19887  Zm00001d013779         9429   3136.500000       9869.5
# 21924      BAC19887  Zm00001d033105         9429   3335.000000       9702.7
#
# [21925 rows x 5 columns]

# %%
top_10_maize_genes_as_rice
# Out:
#                          One           Two         Three          Four  \
# Zm00001d027267  Os03g0332400  Os02g0232400  Os05g0372400  Os08g0483600
# Zm00001d027268  Os07g0694800  Os02g0828566  Os09g0520600  Os12g0541500
# Zm00001d027276  Os02g0823600  Os11g0265200  Os09g0416800  Os07g0295200
# Zm00001d027283  Os03g0186900  Os04g0654600  Os11g0448700  Os07g0475400
# Zm00001d027292  Os02g0711900  Os06g0717200  Os01g0587300  Os06g0691600
# ...                      ...           ...           ...           ...
# Zm00001d000434  Os09g0442300  Os03g0440900  Os04g0656100  Os08g0107100
# Zm00001d000435  Os10g0498700  Os10g0115600  Os04g0488000  Os05g0510300
# Zm00001d000439  Os04g0600400  Os02g0803400  Os01g0593600  Os05g0402300
# Zm00001d000443  Os02g0110600  Os07g0572600  Os08g0531200  Os07g0620300
# Zm00001d000447  Os05g0584200  Os07g0274700  Os07g0529800  Os01g0185300
#
#                         Five           Six         Seven         Eight  \
# ...

# %%
Number_of_maize_genes = len(top_10_maize_genes_as_rice)
rice_score_divisor = ((Number_of_maize_genes)+(Number_of_maize_genes-1)+(Number_of_maize_genes-2)+(Number_of_maize_genes-3)+(Number_of_maize_genes-4)+(Number_of_maize_genes-5)+(Number_of_maize_genes-6)+(Number_of_maize_genes-7)+(Number_of_maize_genes-8)+(Number_of_maize_genes-9))/10

# %%
Number_of_rice_genes = len(top_10_rice_genes_as_maize)

maize_score_divisor = Number_of_rice_genes-4.5

# %%
maize_score_divisor
# Out:
# 12501.5

# %%
trimmed_all_gene_pairs_for_fc['Rice Score'] = trimmed_all_gene_pairs_for_fc['Rice Score']/rice_score_divisor
trimmed_all_gene_pairs_for_fc['Maize Score'] = trimmed_all_gene_pairs_for_fc['Maize Score']/maize_score_divisor
trimmed_all_gene_pairs_for_fc['Total Score'] = trimmed_all_gene_pairs_for_fc[['Maize Score','Rice Score']].mean(axis = 1)
trimmed_all_gene_pairs_for_fc
# Out:
#                Rice           Maize Group Number  Rice Score  Maize Score  \
# 0      Os05g0199100  Zm00001d037751            0    0.828366     0.936584
# 1      Os05g0199100  Zm00001d008850            0    0.761308     0.952574
# 2      Os01g0195400  Zm00001d037751            0    0.872435     0.890485
# 3      Os01g0195400  Zm00001d008850            0    0.960948     0.970276
# 4      Os01g0825000  Zm00001d043036            1    0.637749     0.716650
# ...             ...             ...          ...         ...          ...
# 21920      BAC19875   GRMZM5G804358         9421    0.970503     0.913474
# 21921      BAC19898  Zm00001d018755         9423    0.477594     0.620134
# 21922      BAC19857   GRMZM5G890451         9428    0.897173     0.886454
# 21923      BAC19887  Zm00001d013779         9429    0.240262     0.789465
# 21924      BAC19887  Zm00001d033105         9429    0.255467     0.776123
#
#        Total Score
# 0         0.882475
# 1         0.856941
# ...

# %%
single_pair_junk_threshold = .7
many_to_many_junk_threshold = .8
difference_between_many_to_drop = .04
### .85 Tolerance = .75,.85,.03
## .7 Tolerance = .7,.8, .02

# %%
list_of_true_pairs = []
list_of_genes_to_average_and_set_to_be_equal = []
for current_group in list(set(trimmed_all_gene_pairs_for_fc['Group Number'].to_list())):
    dataframe_of_group = trimmed_all_gene_pairs_for_fc.loc[trimmed_all_gene_pairs_for_fc['Group Number'] == current_group]
    dataframe_of_group = dataframe_of_group[['Rice','Maize','Total Score']]
    wide_format = dataframe_of_group.pivot(index = 'Rice',columns= 'Maize',values= 'Total Score')
    if (wide_format<single_pair_junk_threshold).all(axis = None):
        continue
    elif wide_format.shape ==(0,0):
        continue
    elif wide_format.shape == (1,1): # Group is 1 to 1, retain Format: Arabidopsis then Maize
        one_true_pair = [wide_format.index.item(),wide_format.columns.item()]
        list_of_true_pairs.append(one_true_pair)
    elif len(wide_format)>1 and len(wide_format.columns) ==1:
        one_true_pair = [wide_format.idxmax(axis =0).item(),wide_format.columns.item()]
        list_of_true_pairs.append(one_true_pair)
    elif len(wide_format) == 1 and len(wide_format.columns)>1:
        one_true_pair = [wide_format.index.item(), wide_format.idxmax(axis = 1).item()]
        list_of_true_pairs.append(one_true_pair)
    else:

        #Drop Low Quality Columns and Rows
        cols_to_drop = wide_format.columns[wide_format.max()<many_to_many_junk_threshold]
        wide_format = wide_format.drop(columns= cols_to_drop)
        rows_to_drop = wide_format.index[wide_format.max(axis = 1)<many_to_many_junk_threshold]
        wide_format = wide_format.drop(index= rows_to_drop)
        if (wide_format<single_pair_junk_threshold).all(axis = None):
            continue
        elif wide_format.shape ==(0,0):
            continue
        elif wide_format.shape == (1,1): # Group is 1 to 1, retain Format: Arabidopsis then Maize
            one_true_pair = [wide_format.index.item(),wide_format.columns.item()]
            list_of_true_pairs.append(one_true_pair)
        elif len(wide_format)>1 and len(wide_format.columns) ==1:
            one_true_pair = [wide_format.idxmax(axis =0).item(),wide_format.columns.item()]
            list_of_true_pairs.append(one_true_pair)
        elif len(wide_format) == 1 and len(wide_format.columns)>1:
            one_true_pair = [wide_format.index.item(), wide_format.idxmax(axis = 1).item()]
            list_of_true_pairs.append(one_true_pair)
        elif (wide_format>.9).all(axis = None):
            ### Put in retention code here
            both_gene_lists_to_average = [wide_format.index.to_list(), wide_format.columns.to_list()]
            list_of_genes_to_average_and_set_to_be_equal.append(both_gene_lists_to_average)
            
        else:
            for cur_row in wide_format.iterrows():
                cur_row_max = cur_row[1].max()
                cur_row[1][cur_row[1]< cur_row_max - difference_between_many_to_drop] = np.nan
                wide_format.loc[cur_row[0]] = cur_row[1]
            wide_format = wide_format.dropna(axis = 1, how = 'all')
            for cur_col in wide_format.columns:
                cur_col_max = wide_format[cur_col].max()
                wide_format[cur_col].loc[wide_format[cur_col]< cur_col_max-difference_between_many_to_drop] = np.nan
            wide_format = wide_format.dropna(axis = 0, how = 'all')
            col_count = wide_format.count() == 1
            wide_format = wide_format.loc[:,col_count]
            row_count = wide_format.count(axis = 1) ==1 
            wide_format = wide_format.loc[row_count,:]
            wide_format = wide_format.dropna(axis = 1, how = 'all')
            wide_format = wide_format.dropna(axis = 0, how = 'all')
            for label,content in wide_format.items():
                cur_maize_label = label
                cur_rice_label = content.idxmax()
                if type(cur_rice_label) == str:
                    one_true_pair = [cur_rice_label,cur_maize_label]
                    list_of_true_pairs.append(one_true_pair)

# %%
true_pair_dataframe = pd.DataFrame(columns= ['Rice Gene','Maize Gene'], data = list_of_true_pairs)
true_pair_dataframe = true_pair_dataframe.drop_duplicates(subset = 'Rice Gene')
true_pair_dataframe = true_pair_dataframe.drop_duplicates(subset = 'Maize Gene')
true_pair_dataframe
# Out:
#          Rice Gene      Maize Gene
# 0     Os01g0195400  Zm00001d008850
# 1     Os05g0199100  Zm00001d037751
# 2     Os01g0101600  Zm00001d008390
# 3     Os01g0256800  Zm00001d008326
# 4     Os01g0847100  Zm00001d042875
# ...            ...             ...
# 7652      BAC19863   GRMZM5G898647
# 7653      BAC19893   GRMZM5G867512
# 7654      BAC19869   GRMZM5G861791
# 7655      BAC19875   GRMZM5G804358
# 7656      BAC19857   GRMZM5G890451
#
# [7657 rows x 2 columns]

# %%
# current_group = trimmed_maize_arab_map.loc[trimmed_maize_arab_map['Group ID'] ==1590] ## Possible Examples : 0, 586, 3059, 2690, 3515
# #current_group
# alpha_rows = []
# beta_columns = []
# for arab_gene in set(current_group['arabidopsis'].to_list()):
#     if arab_gene in alpha_half_of_genes:
#         alpha_rows.append(arab_gene)
#     if arab_gene in beta_half_of_genes:
#         beta_columns.append(arab_gene)
        
# subset_dataframe =  arab_cococonet_alpha_half.loc[arab_cococonet_alpha_half.index.isin(alpha_rows)]
# subset_dataframe = subset_dataframe[subset_dataframe.columns.intersection(beta_columns)]
# subset_dataframe

# %%
trimmed_all_gene_pairs_for_fc
# Out:
#                Rice           Maize Group Number  Rice Score  Maize Score  \
# 0      Os05g0199100  Zm00001d037751            0    0.828366     0.936584
# 1      Os05g0199100  Zm00001d008850            0    0.761308     0.952574
# 2      Os01g0195400  Zm00001d037751            0    0.872435     0.890485
# 3      Os01g0195400  Zm00001d008850            0    0.960948     0.970276
# 4      Os01g0825000  Zm00001d043036            1    0.637749     0.716650
# ...             ...             ...          ...         ...          ...
# 21920      BAC19875   GRMZM5G804358         9421    0.970503     0.913474
# 21921      BAC19898  Zm00001d018755         9423    0.477594     0.620134
# 21922      BAC19857   GRMZM5G890451         9428    0.897173     0.886454
# 21923      BAC19887  Zm00001d013779         9429    0.240262     0.789465
# 21924      BAC19887  Zm00001d033105         9429    0.255467     0.776123
#
#        Total Score
# 0         0.882475
# 1         0.856941
# ...

# %%
trimmed_all_gene_pairs_for_fc['Group Number'].value_counts().head(20)
# Out:
# 939     255
# 19      176
# 659     121
# 116     120
# 1473    110
# 553      99
# 364      98
# 3702     77
# 918      77
# 1735     72
# 1618     70
# 1175     64
# 1058     64
# 255      63
# 330      63
# 3810     56
# 827      56
# 1095     56
# 7041     54
# 4048     50
# Name: Group Number, dtype: int64

# %%
trimmed_all_gene_pairs_for_fc_ninenine = trimmed_all_gene_pairs_for_fc.loc[trimmed_all_gene_pairs_for_fc['Total Score'] >.95]
trimmed_all_gene_pairs_for_fc_ninenine['Group Number'].value_counts().head(40)
# Out:
# 216     15
# 676     15
# 2919    14
# 1231    14
# 2097    11
# 1473    11
# 1936    10
# 3017     9
# 2053     9
# 2839     8
# 5092     7
# 2244     7
# 1573     7
# 2641     7
# 4322     6
# 7549     6
# 1103     6
# 1713     6
# 4146     6
# 659      6
# 4330     6
# 725      6
# 7271     6
# 6760     6
# 3071     5
# 3636     5
# 2100     5
# 3223     5
# 1571     5
# 2678     5
# 4015     4
# 2701     4
# 3876     4
# 2648     4
# 1588     4
# 4990     4
# 2796     4
# 6672     4
# 5410     4
# 649      4
# Name: Group Number, dtype: int64

# %%
current_group = 649
dataframe_of_group = trimmed_all_gene_pairs_for_fc.loc[trimmed_all_gene_pairs_for_fc['Group Number'] == current_group]
dataframe_of_group = dataframe_of_group[['Rice','Maize','Total Score']]
wide_format = dataframe_of_group.pivot(index = 'Rice',columns= 'Maize',values= 'Total Score')
wide_format
# Out:
# Maize         Zm00001d008491  Zm00001d012103  Zm00001d023559  Zm00001d042453  \
# Rice
# Os01g0118000        0.928756        0.920366        0.308933        0.923780
# Os01g0905800        0.830566        0.852533        0.315440        0.835493
# Os06g0608700        0.351304        0.264854        0.986444        0.248559
# Os10g0163340        0.473522        0.513993        0.234460        0.536617
# Os11g0171300        0.231867        0.210988        0.995236        0.186502
#
# Maize         Zm00001d053015
# Rice
# Os01g0118000        0.254401
# Os01g0905800        0.326492
# Os06g0608700        0.982359
# Os10g0163340        0.312464
# Os11g0171300        0.991154

# %%
#true_pair_dataframe.to_csv('/data/passala/Generated_Tables/Maize_Rice_integration/true_pair_dataframe_default_settigns.csv', index = False)
